# %% [markdown]
# ## QUESTÃO 1:
#
# Escreva os códigos em Python modularizados e com tratamento de exceções para
# resolver os problemas a seguir:
# - A: Desenvolver um algoritmo que construa uma lista de tuplas com nome e salário de
# funcionários. Em seguida, o código deve recalcular os salários considerando os seguintes
# aumentos:
# • 20% para salários de até R$2.000,00;
# • 15% para salários entre R$2.000,00 e R$5.000,00;
# • 5% para salários maiores que R$5.000,00;
# - Por fim, o código deve exibir o total de aumento total dos salários novos menos o total de
# salários antigos e os nomes dos funcionários com salários menores que R$2.000,00.
#
#  RESPOSTA DO DIEGO:

# %%
lista_funcionarios = []

print(f'Informe os dados dos funcionários:')
for cont in range(2):
    funcionario = input("nome: ")
    salario = float(input("salario: "))
    reajuste = salario * 100 / 100
    dadosF = (funcionario, salario, reajuste)
    lista_funcionarios.append(dadosF)

for dadosF in lista_funcionarios:
    funcionario, salario, reajuste = dadosF
    if salario <= 2000:
        reajuste = (salario * 20 / 100) + salario
        dadosF = (funcionario, salario, reajuste)
        print(f'funcionario: ', funcionario,'salario: ', salario, 'reajuste: ', reajuste)

    elif salario > 2000 and salario <= 5000:
        reajuste = (salario * 15 / 100) + salario
        dadosF = (funcionario, salario, reajuste)
        print(f'funcionario: ', funcionario,'salario: ', salario, 'reajuste: ', reajuste)

    elif salario > 5000:
        reajuste = (salario * 5 / 100) + salario
        dadosF = (funcionario, salario, reajuste)
        print(f'funcionario: ', funcionario,'salario: ', salario, 'reajuste: ', reajuste)

# %% [markdown]
# RESPOSTA DO AUTOR DO LIVRO: (muito melhor pq ele usa funções, não foi especificado na questão então não usei, mas é importante para padrões de projeto e evitar duplicação de código)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## QUESTÃO 2
#
# Construir um simulador de urna eletrônica. Inicialmente, o simulador deve permitir o
# cadastro de candidatos. O usuário pode cadastrar quantos candidatos desejar. O cadastro
# de um candidato envolve um número e seu nome. O número deve ser armazenado em
# formato textual, mas deve possuir exatamente dois dígitos numéricos. A função isdigit() do
# tipo textual pode ser usada para verificar se o texto é um número válido. Por fim, os
# candidatos cadastrados devem ser mantidos em um dicionário (número: nome).
#
# - Resposta do Diego:

# %%
lista_candidatos = {}

while True:
        
        print(f'digite os dados do candidato (ou digite sair para encerrar)')
        nome = input('nome do candidato: ')
        if nome.lower() == 'sair':
            break

        cod = input('digite o numero de dois digitos do candidato: ')

        if cod.isdigit():
            cod = int(cod)
            lista_candidatos[nome] = cod
        else:
            print('código inválido:')

        print('candidato adicionado!')

print(f'candidatos cadastrados: ')
for nome, cod in lista_candidatos.items():
    
    print(f'nome: {nome}, codigo: {cod}')

# %% [markdown]
# - Resposta do autor:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# O dele é mais completo no sentido de possibilitar também a votação.
